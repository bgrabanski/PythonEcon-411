# %%
import pandas as pd
import pandas_datareader.data as web
import yfinance as yf
import datetime
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip uninstall yfinance

# %%
print(yf.__version__)
# Out:
# 0.2.12

# %%
ticker_list = ["MSFT", "AAPL", "TSLA", "ENPH"]

ex = yf.Ticker("MSFT")


for key in dir(ex):
    try:
        print(key)
        print(getattr(ex, key))
    except:
        continue
# Out:
# __class__
# <class 'yfinance.ticker.Ticker'>
# __delattr__
# <method-wrapper '__delattr__' of Ticker object at 0x0000029B24C54D90>
# __dict__
# {'ticker': 'MSFT', 'session': None, '_history': None, '_history_metadata': None, '_base_url': 'https://query2.finance.yahoo.com', '_scrape_url': 'https://finance.yahoo.com/quote', '_tz': None, '_isin': None, '_news': [], '_shares': None, '_earnings_dates': {}, '_earnings': None, '_financials': None, '_data': <yfinance.data.TickerData object at 0x0000029B23589640>, '_analysis': <yfinance.scrapers.analysis.Analysis object at 0x0000029B235890A0>, '_holders': <yfinance.scrapers.holders.Holders object at 0x0000029B1FE4E130>, '_quote': <yfinance.scrapers.quote.Quote object at 0x0000029B1FE4ED60>, '_fundamentals': <yfinance.scrapers.fundamentals.Fundamentals object at 0x0000029B1FE4EEB0>, '_fast_info': lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow'], '_expirations': {}}
# __dir__
# <built-in method __dir__ of Ticker object at 0x0000029B24C54D90>
# __doc__
# None
# __eq__
# <method-wrapper '__eq__' of Ticker object at 0x0000029B24C54D90>
# __format__
# <built-in method __format__ of Ticker object at 0x0000029B24C54D90>
# __ge__
# <method-wrapper '__ge__' of Ticker object at 0x0000029B24C54D90>
# __getattribute__
# <method-wrapper '__getattribute__' of Ticker object at 0x0000029B24C54D90>
# __gt__
# <method-wrapper '__gt__' of Ticker object at 0x0000029B24C54D90>
# __hash__
# <method-wrapper '__hash__' of Ticker object at 0x0000029B24C54D90>
# __init__
# <bound method Ticker.__init__ of yfinance.Ticker object <MSFT>>
# __init_subclass__
# <built-in method __init_subclass__ of type object at 0x0000029B20F636B0>
# __le__
# <method-wrapper '__le__' of Ticker object at 0x0000029B24C54D90>
# __lt__
# <method-wrapper '__lt__' of Ticker object at 0x0000029B24C54D90>
# __module__
# yfinance.ticker
# __ne__
# <method-wrapper '__ne__' of Ticker object at 0x0000029B24C54D90>
# __new__
# <built-in method __new__ of type object at 0x00007FFC4B0ADE00>
# __reduce__
# <built-in method __reduce__ of Ticker object at 0x0000029B24C54D90>
# __reduce_ex__
# <built-in method __reduce_ex__ of Ticker object at 0x0000029B24C54D90>
# __repr__
# <bound method Ticker.__repr__ of yfinance.Ticker object <MSFT>>
# __setattr__
# <method-wrapper '__setattr__' of Ticker object at 0x0000029B24C54D90>
# __sizeof__
# <built-in method __sizeof__ of Ticker object at 0x0000029B24C54D90>
# __str__
# <method-wrapper '__str__' of Ticker object at 0x0000029B24C54D90>
# __subclasshook__
# <built-in method __subclasshook__ of type object at 0x0000029B20F636B0>
# __weakref__
# None
# _analysis
# <yfinance.scrapers.analysis.Analysis object at 0x0000029B235890A0>
# _base_url
# https://query2.finance.yahoo.com
# _data
# <yfinance.data.TickerData object at 0x0000029B23589640>
# _download_options
# <bound method Ticker._download_options of yfinance.Ticker object <MSFT>>
# _earnings
# None
# _earnings_dates
# {}
# _expirations
# {}
# _fast_info
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']
# _fetch_ticker_tz
# <bound method TickerBase._fetch_ticker_tz of yfinance.Ticker object <MSFT>>
# _financials
# None
# _fix_unit_mixups
# <bound method TickerBase._fix_unit_mixups of yfinance.Ticker object <MSFT>>
# _fix_zeroes
# <bound method TickerBase._fix_zeroes of yfinance.Ticker object <MSFT>>
# _fundamentals
# <yfinance.scrapers.fundamentals.Fundamentals object at 0x0000029B1FE4EEB0>
# _get_ticker_tz
# <bound method TickerBase._get_ticker_tz of yfinance.Ticker object <MSFT>>
# _history
# None
# _history_metadata
# None
# _holders
# <yfinance.scrapers.holders.Holders object at 0x0000029B1FE4E130>
# _isin
# None
# _news
# []
# _options2df
# <bound method Ticker._options2df of yfinance.Ticker object <MSFT>>
# _quote
# <yfinance.scrapers.quote.Quote object at 0x0000029B1FE4ED60>
# _reconstruct_intervals_batch
# <bound method TickerBase._reconstruct_intervals_batch of yfinance.Ticker object <MSFT>>
# _scrape_url
# https://finance.yahoo.com/quote
# _shares
# None
# _tz
# None
# actions
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00       0.00           2.0
# 1990-04-16 00:00:00-04:00       0.00           2.0
# 1991-06-27 00:00:00-04:00       0.00           1.5
# 1992-06-15 00:00:00-04:00       0.00           1.5
# 1994-05-23 00:00:00-04:00       0.00           2.0
# ...                              ...           ...
# 2022-02-16 00:00:00-05:00       0.62           0.0
# 2022-05-18 00:00:00-04:00       0.62           0.0
# 2022-08-17 00:00:00-04:00       0.62           0.0
# 2022-11-16 00:00:00-05:00       0.68           0.0
# 2023-02-15 00:00:00-05:00       0.68           0.0
#
# [86 rows x 2 columns]
# analyst_price_target
# balance_sheet
# balancesheet
# basic_info
# WARNING: 'Ticker.basic_info' is renamed to 'Ticker.fast_info', hopefully purpose is clearer
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']
# calendar
# capital_gains
# []
# cash_flow
# cashflow
# dividends
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2022-02-16 00:00:00-05:00    0.62
# 2022-05-18 00:00:00-04:00    0.62
# 2022-08-17 00:00:00-04:00    0.62
# 2022-11-16 00:00:00-05:00    0.68
# 2023-02-15 00:00:00-05:00    0.68
# Name: Dividends, Length: 77, dtype: float64
# earnings
# earnings_dates
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2024-01-22 16:00:00-05:00           NaN           NaN          NaN
# 2024-01-22 05:00:00-05:00           NaN           NaN          NaN
# 2023-10-23 06:00:00-04:00           NaN           NaN          NaN
# 2023-07-24 06:00:00-04:00           NaN           NaN          NaN
# 2023-04-24 06:00:00-04:00          2.23           NaN          NaN
# 2023-01-24 11:00:00-05:00          2.30          2.32       0.0109
# 2022-10-25 12:00:00-04:00          2.30          2.35       0.0204
# 2022-07-26 12:00:00-04:00          2.29          2.23      -0.0275
# 2022-04-26 12:00:00-04:00          2.19          2.22       0.0160
# 2022-01-25 11:00:00-05:00          2.31          2.48       0.0727
# 2021-10-26 12:00:00-04:00          2.08          2.27       0.0940
# 2021-07-27 12:00:00-04:00          1.92          2.17       0.1326
# earnings_forecasts
# None
# earnings_trend
# None
# fast_info
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']
# financials
# get_actions
# <bound method TickerBase.get_actions of yfinance.Ticker object <MSFT>>
# get_analyst_price_target
# <bound method TickerBase.get_analyst_price_target of yfinance.Ticker object <MSFT>>
# get_balance_sheet
# <bound method TickerBase.get_balance_sheet of yfinance.Ticker object <MSFT>>
# get_balancesheet
# <bound method TickerBase.get_balancesheet of yfinance.Ticker object <MSFT>>
# get_calendar
# <bound method TickerBase.get_calendar of yfinance.Ticker object <MSFT>>
# get_capital_gains
# <bound method TickerBase.get_capital_gains of yfinance.Ticker object <MSFT>>
# get_cash_flow
# <bound method TickerBase.get_cash_flow of yfinance.Ticker object <MSFT>>
# get_cashflow
# <bound method TickerBase.get_cashflow of yfinance.Ticker object <MSFT>>
# get_dividends
# <bound method TickerBase.get_dividends of yfinance.Ticker object <MSFT>>
# get_earnings
# <bound method TickerBase.get_earnings of yfinance.Ticker object <MSFT>>
# get_earnings_dates
# <bound method TickerBase.get_earnings_dates of yfinance.Ticker object <MSFT>>
# get_earnings_forecast
# <bound method TickerBase.get_earnings_forecast of yfinance.Ticker object <MSFT>>
# get_earnings_trend
# <bound method TickerBase.get_earnings_trend of yfinance.Ticker object <MSFT>>
# get_financials
# <bound method TickerBase.get_financials of yfinance.Ticker object <MSFT>>
# get_history_metadata
# <bound method TickerBase.get_history_metadata of yfinance.Ticker object <MSFT>>
# get_income_stmt
# <bound method TickerBase.get_income_stmt of yfinance.Ticker object <MSFT>>
# get_incomestmt
# <bound method TickerBase.get_incomestmt of yfinance.Ticker object <MSFT>>
# get_info
# <bound method TickerBase.get_info of yfinance.Ticker object <MSFT>>
# get_institutional_holders
# <bound method TickerBase.get_institutional_holders of yfinance.Ticker object <MSFT>>
# get_isin
# <bound method TickerBase.get_isin of yfinance.Ticker object <MSFT>>
# get_major_holders
# <bound method TickerBase.get_major_holders of yfinance.Ticker object <MSFT>>
# get_mutualfund_holders
# <bound method TickerBase.get_mutualfund_holders of yfinance.Ticker object <MSFT>>
# get_news
# <bound method TickerBase.get_news of yfinance.Ticker object <MSFT>>
# get_recommendations
# <bound method TickerBase.get_recommendations of yfinance.Ticker object <MSFT>>
# get_recommendations_summary
# <bound method TickerBase.get_recommendations_summary of yfinance.Ticker object <MSFT>>
# get_rev_forecast
# <bound method TickerBase.get_rev_forecast of yfinance.Ticker object <MSFT>>
# get_shares
# <bound method TickerBase.get_shares of yfinance.Ticker object <MSFT>>
# get_shares_full
# <bound method TickerBase.get_shares_full of yfinance.Ticker object <MSFT>>
# get_splits
# <bound method TickerBase.get_splits of yfinance.Ticker object <MSFT>>
# get_sustainability
# <bound method TickerBase.get_sustainability of yfinance.Ticker object <MSFT>>
# get_trend_details
# <bound method TickerBase.get_trend_details of yfinance.Ticker object <MSFT>>
# history
# <bound method TickerBase.history of yfinance.Ticker object <MSFT>>
# history_metadata
# {'currency': 'USD', 'symbol': 'MSFT', 'exchangeName': 'NMS', 'instrumentType': 'EQUITY', 'firstTradeDate': Timestamp('1986-03-13 09:30:00-0500', tz='America/New_York'), 'regularMarketTime': Timestamp('2023-02-22 11:49:13-0500', tz='America/New_York'), 'gmtoffset': -18000, 'timezone': 'EST', 'exchangeTimezoneName': 'America/New_York', 'regularMarketPrice': 252.07, 'chartPreviousClose': 0.097, 'priceHint': 2, 'currentTradingPeriod': {'pre': {'end': Timestamp('2023-02-22 09:30:00-0500', tz='America/New_York'), 'start': Timestamp('2023-02-22 04:00:00-0500', tz='America/New_York')}, 'regular': {'end': Timestamp('2023-02-22 16:00:00-0500', tz='America/New_York'), 'start': Timestamp('2023-02-22 09:30:00-0500', tz='America/New_York')}, 'post': {'end': Timestamp('2023-02-22 20:00:00-0500', tz='America/New_York'), 'start': Timestamp('2023-02-22 16:00:00-0500', tz='America/New_York')}}, 'dataGranularity': '1d', 'range': '', 'validRanges': ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']}
# income_stmt
# incomestmt
# info
# None
# institutional_holders
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  642664898    2022-12-30  0.0863
# 1                     Blackrock Inc.  532042708    2022-12-30  0.0715
# 2           State Street Corporation  294574683    2022-12-30  0.0396
# 3                           FMR, LLC  198985661    2022-12-30  0.0267
# 4      Price (T.Rowe) Associates Inc  168647376    2022-12-30  0.0227
# 5      Geode Capital Management, LLC  142731177    2022-12-30  0.0192
# 6                     Morgan Stanley  119417954    2022-12-30  0.0160
# 7          JP Morgan Chase & Company   93021058    2022-12-30  0.0125
# 8            Capital World Investors   91715063    2022-12-30  0.0123
# 9  Norges Bank Investment Management   86316926    2022-12-30  0.0116
#
#           Value
# 0  161977256577
# 1  134096040552
# 2   74244601125
# 3   50152344662
# 4   42505883514
# 5   35973964892
# 6   30098100324
# 7   23445026833
# 8   23115863862
# 9   21755317449
# isin
# None
# major_holders
#         0                                      1
# 0   0.06%        % of Shares Held by All Insider
# 1  73.76%       % of Shares Held by Institutions
# 2  73.80%        % of Float Held by Institutions
# 3    6123  Number of Institutions Holding Shares
# mutualfund_holders
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  222313847    2022-09-29
# 1                            Vanguard 500 Index Fund  169062762    2022-09-29
# 2                             SPDR S&P 500 ETF Trust   82250000    2022-12-30
# 3                            Fidelity 500 Index Fund   81679555    2022-12-30
# 4        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   76335623    2022-12-30
# 5                           iShares Core S&P 500 ETF   66940817    2022-12-30
# 6                         Vanguard Growth Index Fund   61426549    2022-09-29
# 7  Vanguard Institutional Index Fund-Institutiona...   54149972    2022-09-29
# 8                         Growth Fund Of America Inc   44491127    2022-12-30
# 9                 Select Sector SPDR Fund-Technology   34910084    2022-12-30
#
#     % Out        Value
# 0  0.0299  56031980505
# 1  0.0227  42610577399
# 2  0.0110  20730289447
# 3  0.0110  20586514493
# 4  0.0103  19239629908
# 5  0.0090  16871763067
# 6  0.0083  15481946997
# 7  0.0073  13647958579
# 8  0.0060  11213543350
# 9  0.0047   8798737336
# news
# [{'uuid': 'df891454-388d-37d5-a0ee-a0e219cc2655', 'title': 'Microsoft Brings ChatGPT-Powered Bing to Apple, Android Mobile Devices', 'publisher': 'The Wall Street Journal', 'link': 'https://finance.yahoo.com/m/df891454-388d-37d5-a0ee-a0e219cc2655/microsoft-brings.html', 'providerPublishTime': 1677082920, 'type': 'STORY', 'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/gDe.XbcugV4E7t.c7Dwcmg--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/35828a95df718bc6fcec4fdc1055af7e', 'width': 1280, 'height': 640, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/yxPt97ynCTDEuqExFWoWsw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/35828a95df718bc6fcec4fdc1055af7e', 'width': 140, 'height': 140, 'tag': '140x140'}]}, 'relatedTickers': ['AAPL', 'MSFT', 'GOOG', 'GOOGL']}, {'uuid': '1e1dcd10-b923-3d3b-9556-e8d91131ba00', 'title': '12 Most Promising Future Stocks to Buy', 'publisher': 'Insider Monkey', 'link': 'https://finance.yahoo.com/news/12-most-promising-future-stocks-160919538.html', 'providerPublishTime': 1677082159, 'type': 'STORY', 'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/LjsRFvo6k81rHiWoio_3SA--~B/aD0zMjA7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/4dc5660331c59e975b09aafc14f563d2', 'width': 400, 'height': 320, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/URl.c1eWedMlMoLVNy0e1g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/4dc5660331c59e975b09aafc14f563d2', 'width': 140, 'height': 140, 'tag': '140x140'}]}, 'relatedTickers': ['MSFT', 'NVDA', 'ASML', 'AMD', 'IBM', 'DIS', 'SAP', 'ORCL']}, {'uuid': '0a51732f-88f5-3d73-9b96-9f212e434283', 'title': 'More Hurdles Activision Deal? It Did Not Disclose Employee Info Data Breach', 'publisher': 'Benzinga', 'link': 'https://finance.yahoo.com/news/more-hurdles-activision-deal-did-160149553.html', 'providerPublishTime': 1677081709, 'type': 'STORY', 'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/As4BLxvDwBFpG2rwVYOPuA--~B/aD00MDA7dz02MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/Benzinga/e3439f405b086c36178d734b698dd20d', 'width': 600, 'height': 400, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/S4JyQR.c3OCdIsYa4iShSg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Benzinga/e3439f405b086c36178d734b698dd20d', 'width': 140, 'height': 140, 'tag': '140x140'}]}, 'relatedTickers': ['ATVI', 'MSFT']}, {'uuid': '8023dd45-003c-3a66-8f2a-7a303a1b6f3c', 'title': 'FOCUS-For tech giants, AI like Bing and Bard poses billion-dollar search problem', 'publisher': 'Reuters', 'link': 'https://finance.yahoo.com/news/focus-tech-giants-ai-bing-153710437.html', 'providerPublishTime': 1677080230, 'type': 'STORY', 'relatedTickers': ['GOOGL', 'MSFT']}, {'uuid': '3e83211e-4cd0-33d1-b5bf-463780aa1bc4', 'title': 'Bernie Sanders supports companies moving to a 4-day work week. These companies did just that — here’s what happened.', 'publisher': 'MarketWatch', 'link': 'https://finance.yahoo.com/m/3e83211e-4cd0-33d1-b5bf-463780aa1bc4/bernie-sanders-supports.html', 'providerPublishTime': 1677079860, 'type': 'STORY', 'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/gfQ6fuPXjKqRj9B4LF98nQ--~B/aD02NDA7dz0xMjc5O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/marketwatch.com/da7097f5a8727afde21c4b62ef42b34b', 'width': 1279, 'height': 640, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/a6_qUwDrng9otcxMhFEbzw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/marketwatch.com/da7097f5a8727afde21c4b62ef42b34b', 'width': 140, 'height': 140, 'tag': '140x140'}]}, 'relatedTickers': ['MSFT']}, {'uuid': '4b2dcd4c-d13f-3956-9f22-66b36d2b00b8', 'title': 'Microsoft Adds AI-Powered Bing Chat to Mobile Apps', 'publisher': 'Barrons.com', 'link' ...
# option_chain
# <bound method Ticker.option_chain of yfinance.Ticker object <MSFT>>
# options
# ('2023-02-24', '2023-03-03', '2023-03-10', '2023-03-17', '2023-03-24', '2023-03-31', '2023-04-21', '2023-05-19', '2023-06-16', '2023-07-21', '2023-08-18', '2023-09-15', '2023-10-20', '2024-01-19', '2024-06-21', '2024-12-20', '2025-01-17', '2025-06-20', '2025-12-19')
# quarterly_balance_sheet
# quarterly_balancesheet
# quarterly_cash_flow
# quarterly_cashflow
# quarterly_earnings
# Empty DataFrame
# Columns: []
# Index: []
# quarterly_financials
# quarterly_income_stmt
# quarterly_incomestmt
# recommendations
# None
# recommendations_summary
# None
# revenue_forecasts
# None
# session
# None
# shares
# None
# splits
# Date
# 1987-09-21 00:00:00-04:00    2.0
# 1990-04-16 00:00:00-04:00    2.0
# 1991-06-27 00:00:00-04:00    1.5
# 1992-06-15 00:00:00-04:00    1.5
# 1994-05-23 00:00:00-04:00    2.0
# 1996-12-09 00:00:00-05:00    2.0
# 1998-02-23 00:00:00-05:00    2.0
# 1999-03-29 00:00:00-05:00    2.0
# 2003-02-18 00:00:00-05:00    2.0
# Name: Stock Splits, dtype: float64
# stats
# <bound method TickerBase.stats of yfinance.Ticker object <MSFT>>
# sustainability
# None
# ticker
# MSFT

# %%
ex._earnings_history
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8644\1758917642.py in <module>
# ----> 1 ex._earnings_history
#
# AttributeError: 'Ticker' object has no attribute '_earnings_history'
